# %%
#!pip install gmplot

# %%
import pandas as pd

# %%
markets = pd.read_csv('databases/MERCATS_FIRES_CARRER.csv')
markets.name = 'markets'
arts = pd.read_csv('databases/salesartsesceniques-funcions.csv')
arts.name = 'arts'
concerts = pd.read_csv('databases/espaisconcerts-concertsgransauditoris.csv')
concerts.name = 'concerts'

#this db is the same as 'arts'
#shows = pd.read_csv('databases/salesartsesceniques-espectacles.csv')
#shows.name = 'shows'

temp_expos = pd.read_csv('databases/museusexposicions-nombreexposicionstemporals.csv')
temp_expos.name = 'temporary expositions'

# %%
databases = []
databases.append(markets)
databases.append(arts)
databases.append(concerts)
#databases.append(shows)
databases.append(temp_expos)
for db in databases:
    print(db.name)
    print(' # of entries: ',len(db))
    print("Features: ", db.columns.values)
    print("")
# Out:
# markets
#  # of entries:  52
# Features:  ['CODI_CAPA' 'CAPA_GENERICA' 'NOM_CAPA' 'ED50_COORD_X' 'ED50_COORD_Y'
#  'ETRS89_COORD_X' 'ETRS89_COORD_Y' 'LONGITUD' 'LATITUD' 'DISTRICTE'
#  'BARRI' 'NOM_DISTRICTE' 'NOM_BARRI' 'EQUIPAMENT' 'ADRECA' 'TELEFON']
#
# arts
#  # of entries:  56
# Features:  ['Any' 'Ambit' 'Titularitat' 'Entitat' 'TipusEquipament' 'UsosFuncionals'
#  'Equipament' 'Districte' 'Latitud' 'Longitud' 'Web' 'Sala' 'Funcions'
#  'Nota']
#
# concerts
#  # of entries:  3
# Features:  ['Any' 'Ambit' 'Titularitat' 'Entitat' 'TipusEquipament' 'UsosFuncionals'
#  'Equipament' 'Districte' 'Latitud' 'Longitud' 'Web' 'Concerts' 'Nota']
#
# temporary expositions
#  # of entries:  42
# Features:  ['Any' 'Ambit' 'Titularitat' 'Entitat' 'TipusEquipament' 'UsosFuncionals'
#  'Equipament' 'Latitud' 'Longitud' 'Web' 'Seu' 'Districte'
#  'NombreExposicionsTemporals']

# %%
markets
# Out:
#    CODI_CAPA                 CAPA_GENERICA                   NOM_CAPA  \
# 0       F002  Mercats i centres comercials  Mercats i fires al carrer
# 1       F002  Mercats i centres comercials  Mercats i fires al carrer
# 2       F002  Mercats i centres comercials  Mercats i fires al carrer
# 3       F002  Mercats i centres comercials  Mercats i fires al carrer
# 4       F002  Mercats i centres comercials  Mercats i fires al carrer
# 5       F002  Mercats i centres comercials  Mercats i fires al carrer
# 6       F002  Mercats i centres comercials  Mercats i fires al carrer
# 7       F002  Mercats i centres comercials  Mercats i fires al carrer
# 8       F002  Mercats i centres comercials  Mercats i fires al carrer
# 9       F002  Mercats i centres comercials  Mercats i fires al carrer
# 10      F002  Mercats i centres comercials  Mercats i fires al carrer
# 11      F002  Mercats i centres comercials  Mercats i fires al carrer
# ...

# %%
arts
# Out:
#      Any            Ambit                                  Titularitat  \
# 0   2016  Arts escèniques                                      Privada
# 1   2016  Arts escèniques                                      Privada
# 2   2016  Arts escèniques                                      Privada
# 3   2016  Arts escèniques                                      Privada
# 4   2016  Arts escèniques                                      Privada
# 5   2016  Arts escèniques                         Pública no municipal
# 6   2016  Arts escèniques                                      Privada
# 7   2016  Arts escèniques                                      Privada
# 8   2016  Arts escèniques                                      Privada
# 9   2016  Arts escèniques                                      Privada
# 10  2016  Arts escèniques                                      Privada
# 11  2016  Arts escèniques                                      Privada
# ...

# %%
concerts
# Out:
#     Any   Ambit                                  Titularitat  \
# 0  2016  Música  Consorci o fundació amb presència municipal
# 1  2016  Música  Consorci o fundació amb presència municipal
# 2  2016  Música  Consorci o fundació amb presència municipal
#
#                                              Entitat  TipusEquipament  \
# 0                 Consorci del Gran Teatre del Liceu  Grans auditoris
# 1               Consorci de L'Auditori i l'Orquestra  Grans auditoris
# 2  Fundació Orfeó Català-Palau de la Música Catalana  Grans auditoris
#
#     UsosFuncionals                   Equipament         Districte    Latitud  \
# 0  Grans auditoris        Gran Teatre del Liceu  01. Ciutat Vella  41.380115
# 1  Grans auditoris                   L'Auditori      02. Eixample  41.398741
# 2  Grans auditoris  Palau de la Música Catalana  01. Ciutat Vella  41.387332
#
#    Longitud                             Web  Concerts  Nota
# 0  2.173329  http://www.liceubarcelona.cat/       125   NaN
# ...

# %%
temp_expos
# Out:
#      Any               Ambit                                  Titularitat  \
# 0   2016  Història i memòria                                    Municipal
# 1   2016  Història i memòria                                    Municipal
# 2   2016        Arts visuals                                      Privada
# 3   2016  Història i memòria                                    Municipal
# 4   2016        Arts visuals  Consorci o fundació amb presència municipal
# 5   2016             Ciència                                      Privada
# 6   2016  Història i memòria                                    Municipal
# 7   2016        Arts visuals                                      Privada
# 8   2016        Arts visuals                                    Municipal
# 9   2016        Arts visuals  Consorci o fundació amb presència municipal
# 10  2016        Arts visuals                                      Privada
# 11  2016        Arts visuals                                      Privada
# ...
