# %% [markdown]
# ## Create db and collections

# %%
import pymongo

# Connection to Mongo DB
try:
    conn=pymongo.MongoClient()
    print ("Connected successfully!!!")
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
conn
# Out:
# Connected successfully!!!
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
# create db
db = conn['events']
print (db)
conn.database_names()
# Empty db doesn't show
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'events')
# ['admin', 'config', 'events', 'local']

# %%
# A collection is the equivalent to a table in rdbms
collection = db.opendata
db.collection_names()
# Empty collections don't show
# Out:
# ['opendata']

# %% [markdown]
# ## Read data

# %%
import pandas as pd

# %%
cnames = ['lat', #0
          'long', #1
          'event_type', #2
          'address', #3 
          'start_date', #4
          'end_date', #5
          'event_info', #6
          'web', #7
          'image', #8
          'tickets', #9
          'year', #10
          'location' #11
         ]

# %% [markdown]
# ### Street markets data set

# %%
def drop_columns(data):
    drop_columns = list(set(data.columns) - set(cnames))
    data = data.drop(drop_columns, axis = 1)
    return(data)
def rename_cols_street_markets(cnames, data):
    data = data.rename(columns={'NOM_CAPA':cnames[2], 'LONGITUD':cnames[1], 'LATITUD': cnames[0],
                                   'ADRECA': cnames[3] })
    data[cnames[2]] = 'Street Markets'
    return(data)
def load_and_prepare_data(cnames, rename_cols_fct, path):
    data = pd.read_csv(path)
    data = rename_cols_fct(cnames, data)
    data = drop_columns(data)
    return(data)
def rename_cols_street_markets(cnames, data):
    data.rename(columns={'NOM_CAPA':cnames[2], 'LONGITUD':cnames[1], 'LATITUD': cnames[0],
                                   'ADRECA': cnames[3] }, inplace = True)
    data[cnames[2]] = 'Street Markets'
    return(data)
def rename_cols_cultural_activities(cnames, data):
    data = data.rename(columns={'Data fi':cnames[5], 'Data inici':cnames[4], 'Descripció': cnames[6],
                                   'Enllaços': cnames[7], 'Imatges': cnames[8], 'Entrades': cnames[9]})
    return(data)
def write_db(data, data_name):
    try:
        collection.insert_many(data.to_dict("records"))
        print("%s data successfully written to DB!!!" % data_name)
    except pymongo.errors.WriteError as e:
        print("Could not write %s data to DB: %s" % (data_name, e))

# %% [markdown]
# ### Street Marketes

# %%
street_markets = load_and_prepare_data(cnames, rename_cols_street_markets, "../datasets/OpenDataBCN/street_markets.csv")
write_db(street_markets, "Street Markets")
# Out:
# Street Markets data successfully written to DB!!!

# %% [markdown]
# ### Cultural Activities

# %%
cultural_activities = load_and_prepare_data(cnames, rename_cols_cultural_activities, "../datasets/OpenDataBCN/cultural_activities.csv")
collection.insert_many(cultural_activities.to_dict("records"))

# %% [markdown]
# ### Temporary Expos

# %%
pd.read_csv("../datasets/OpenDataBCN/temporary_expos.csv")
def rename_cols_cultural_activities(cnames, data):
    data = data.rename(columns={'Any':cnames[10], 'Latitud':cnames[0], 'Longitud': cnames[1],
                                   'Web': cnames[7], 'Seu': cnames[]})
    return(data)
# Out:
#      Any               Ambit                                  Titularitat  \
# 0   2016  Història i memòria                                    Municipal
# 1   2016  Història i memòria                                    Municipal
# 2   2016        Arts visuals                                      Privada
# 3   2016  Història i memòria                                    Municipal
# 4   2016        Arts visuals  Consorci o fundació amb presència municipal
# 5   2016             Ciència                                      Privada
# 6   2016  Història i memòria                                    Municipal
# 7   2016        Arts visuals                                      Privada
# 8   2016        Arts visuals                                    Municipal
# 9   2016        Arts visuals  Consorci o fundació amb presència municipal
# 10  2016        Arts visuals                                      Privada
# 11  2016        Arts visuals                                      Privada
# 12  2016        Arts visuals  Consorci o fundació amb presència municipal
# 13  2016        Arts visuals                                      Privada
# 14  2016        Arts visuals                                      Privada
# 15  2016        Arts visuals                                    Municipal
# 16  2016  Història i memòria                                      Privada
# 17  2016        Arts visuals                                    Municipal
# 18  2016        Arts visuals                                      Privada
# 19  2016        Arts visuals                                    Municipal
# 20  2016             Ciència  Consorci o fundació amb presència municipal
# 21  2016             Ciència  Consorci o fundació amb presència municipal
# 22  2016        Arts visuals                                    Municipal
# 23  2016        Arts visuals                                    Municipal
# 24  2016  Història i memòria  Consorci o fundació amb presència municipal
# 25  2016  Història i memòria                                    Municipal
# 26  2016  Història i memòria                                    Municipal
# 27  2016  Història i memòria                                    Municipal
# 28  2016        Arts visuals  Consorci o fundació amb presència municipal
# 29  2016  Història i memòria                         Pública no municipal
# 30  2016  Història i memòria                                      Privada
# 31  2016  Història i memòria  Consorci o fundació amb presència municipal
# 32  2016        Arts visuals                                      Privada
# 33  2016  Història i memòria                                      Privada
# 34  2016        Arts visuals                                    Municipal
# 35  2016        Arts visuals  Consorci o fundació amb presència municipal
# 36  2016  Història i memòria                                    Municipal
# 37  2016        Arts visuals  Consorci o fundació amb presència municipal
# 38  2016  Història i memòria                         Pública no municipal
# 39  2016        Arts visuals                         Pública no municipal
# 40  2016  Història i memòria  Consorci o fundació amb presència municipal
# 41  2016  Història i memòria                                    Municipal
#
#                                               Entitat  \
# 0        Institut de Cultura. Ajuntament de Barcelona
# 1        Institut de Cultura. Ajuntament de Barcelona
# 2                                 Fundació "la Caixa"
# 3        Institut de Cultura. Ajuntament de Barcelona
# 4                                                CCCB
# 5                                 Fundació "la Caixa"
# 6        Institut de Cultura. Ajuntament de Barcelona
# 7                                 Fundació Vila Casas
# 8        Institut de Cultura. Ajuntament de Barcelona
# 9                              Fundació Antoni Tàpies
# 10                           Fundació Foto Colectània
# 11                               Fundació Fran Daurel
# 12                                 Fundació Joan Miró
# 13                      Fundació Josep I. Suñol Soler
# 14                                   Fundación Mapfre
# 15       Institut de Cultura. Ajuntament de Barcelona
# 16                   Hemp Museums BV Sucursal Espanya
# 17       Institut de Cultura. Ajuntament de Barcelona
# 18                    Fundació Catalunya - La Pedrera
# 19       Institut de Cultura. Ajuntament de Barcelona
# 20  Consorci del Museu de Ciències Naturals de Bar...
# 21  Consorci del Museu de Ciències Naturals de Bar...
# 22       Institut de Cultura. Ajuntament de Barcelona
# 23       Institut de Cultura. Ajuntament de Barcelona
# 24  Consorci de les Drassanes Reials i Museu Marít...
# 25       Institut de Cultura. Ajuntament de Barcelona
# 26                            Ajuntament de Barcelona
# 27       Institut de Cultura. Ajuntament de Barcelona
# 28              Museu d'Art Contemporani de Barcelona
# 29                           Generalitat de Catalunya
# 30                          Fundació Museu de la Moto
# 31               Consorci de L'Auditori i l'Orquestra
# 32                            Gothsland Art i Cultura
# 33                         Fundació Arqueològica Clos
# 34       Institut de Cultura. Ajuntament de Barcelona
# 35                  Museu Nacional d'Art de Catalunya
# 36                        Fundació Barcelona Olímpica
# 37                             Fundació Museu Picasso
# 38                             Diputació de Barcelona
# 39                           Generalitat de Catalunya
# 40  Fundació Privada de l'Hospital de la Santa Cre...
# 41       Institut de Cultura. Ajuntament de Barcelona
#
#                    TipusEquipament         UsosFuncionals  \
# 0                           Arxius  Centres d'exposicions
# 1                           Arxius  Centres d'exposicions
# 2            Centres d'exposicions  Centres d'exposicions
# 3            Museus i col·leccions   Centres patrimonials
# 4            Centres d'exposicions  Centres d'exposicions
# 5            Museus i col·leccions   Centres patrimonials
# 6            Museus i col·leccions   Centres patrimonials
# 7            Centres d'exposicions  Centres d'exposicions
# 8            Centres d'exposicions  Centres d'exposicions
# 9            Museus i col·leccions   Centres patrimonials
# 10           Museus i col·leccions   Centres patrimonials
# 11           Museus i col·leccions   Centres patrimonials
# 12           Museus i col·leccions   Centres patrimonials
# 13           Museus i col·leccions   Centres patrimonials
# 14           Centres d'exposicions  Centres d'exposicions
# 15           Museus i col·leccions   Centres patrimonials
# 16           Museus i col·leccions   Centres patrimonials
# 17           Centres d'exposicions  Centres d'exposicions
# 18  Espais d'interès arquitectònic   Centres patrimonials
# 19           Centres d'exposicions  Centres d'exposicions
# 20           Museus i col·leccions   Centres patrimonials
# 21           Museus i col·leccions   Centres patrimonials
# 22           Museus i col·leccions   Centres patrimonials
# 23           Museus i col·leccions   Centres patrimonials
# 24           Museus i col·leccions   Centres patrimonials
# 25           Museus i col·leccions   Centres patrimonials
# 26           Museus i col·leccions   Centres patrimonials
# 27           Museus i col·leccions   Centres patrimonials
# 28           Museus i col·leccions   Centres patrimonials
# 29           Museus i col·leccions   Centres patrimonials
# 30           Museus i col·leccions   Centres patrimonials
# 31           Museus i col·leccions   Centres patrimonials
# 32           Museus i col·leccions   Centres patrimonials
# 33           Museus i col·leccions   Centres patrimonials
# 34           Museus i col·leccions   Centres patrimonials
# 35           Museus i col·leccions   Centres patrimonials
# 36           Museus i col·leccions   Centres patrimonials
# 37           Museus i col·leccions   Centres patrimonials
# 38  Espais d'interès arquitectònic   Centres patrimonials
# 39           Centres d'exposicions  Centres d'exposicions
# 40  Espais d'interès arquitectònic   Centres patrimonials
# 41           Museus i col·leccions   Centres patrimonials
#
#                                            Equipament    Latitud  Longitud  \
# 0                       Arxiu Fotogràfic de Barcelona  41.386873  2.181806
# 1            Arxiu Històric de la Ciutat de Barcelona  41.384254  2.175867
# 2                                          CaixaForum  41.371295  2.149575
# 3                                 Castell de Montjuïc  41.367565  2.168531
# 4   Centre de Cultura Contemporània de Barcelona. ...  41.383883  2.166795
# 5                                          CosmoCaixa  41.413267  2.130658
# 6                 El Born Centre de Cultura i Memòria  41.385641  2.183568
# 7        Espais VolART i VolART2. Fundació Vila Casas  41.390963  2.175294
# 8           Fabra i Coats - Centre d'Art Contemporani  41.433763  2.190816
# 9                              Fundació Antoni Tàpies  41.391522  2.163758
# 10                           Fundació Foto Colectania  41.387635  2.182739
# 11                               Fundació Fran Daurel  41.369117  2.146725
# 12                                 Fundació Joan Miró  41.368630  2.159851
# 13                                     Fundació Suñol  41.395558  2.161210
# 14             Fundación Mapfre Casa Garriga i Nogués  41.388888  2.165235
# 15                     Museu del Disseny de Barcelona  41.402570  2.188033
# 16                Hash Marihuana Cáñamo & Hemp Museum  41.380783  2.180139
# 17                                         La Capella  41.381057  2.169794
# 18                                         La Pedrera  41.395316  2.162043
# 19                    La Virreina Centre de la Imatge  41.382498  2.171709
# 20            Museu de Ciències Naturals de Barcelona  41.410780  2.220483
# 21            Museu de Ciències Naturals de Barcelona  41.410780  2.220483
# 22              Museu Etnològic i de Cultures del Món  41.369062  2.155983
# 23              Museu Etnològic i de Cultures del Món  41.369062  2.155983
# 24                    Museu Marítim de Barcelona. MMB        NaN       NaN
# 25               Museu d'Història de Barcelona. MUHBA  41.384316  2.177521
# 26               Museu d'Història de Barcelona. MUHBA  41.384316  2.177521
# 27               Museu d'Història de Barcelona. MUHBA  41.384316  2.177521
# 28       Museu d'Art Contemporani de Barcelona. MACBA  41.383146  2.167831
# 29                      Museu d'Història de Catalunya  41.380669  2.185503
# 30                                   Museu de la Moto  41.383402  2.174488
# 31                                 Museu de la Música  41.398367  2.184868
# 32                        Museu del Modernisme Català  41.388876  2.163385
# 33                          Museu Egipci de Barcelona  41.393626  2.164736
# 34                               Museu Frederic Marès  41.384174  2.176939
# 35            Museu Nacional d'Art de Catalunya. MNAC  41.368854  2.153363
# 36  Museu Olímpic i de l'Esport Joan Antoni Samaranch  41.366249  2.157076
# 37                                      Museu Picasso  41.385152  2.180835
# 38                                        Palau Güell  41.379175  2.174413
# 39                                       Palau Robert  41.396101  2.159514
# 40                     Recinte Modernista de Sant Pau  41.411841  2.174403
# 41         Reial Monestir de Santa Maria de Pedralbes  41.395574  2.112057
#
#                                        Web  \
# 0           http://arxiufotografic.bcn.cat
# 1       http://barcelona.cat/arxiuhistoric
# 2   http://caixaforum.es/es/barcelona/home
# 3     http://www.bcn.cat/castelldemontjuic
# 4                      http://www.cccb.org
# 5             http://obrasocial.lacaixa.es
# 6      http://elborncentrecultural.bcn.cat
# 7         http://www.fundaciovilacasas.com
# 8                http://centredart.bcn.cat
# 9            http://www.fundaciotapies.org
# 10                http://www.colectania.es
# 11       http://www.fundaciofrandaurel.org
# 12                https://www.fmirobcn.org
# 13            http://www.fundaciosunol.org
# 14         https://www.fundacionmapfre.org
# 15          http://www.museudeldisseny.cat
# 16                   http://hashmuseum.com
# 17                http://lacapella.bcn.cat
# 18                http://www.lapedrera.com
# 19               http://lavirreina.bcn.cat
# 20         http://www.jardibotanic.bcn.cat
# 21        http://www.museuciencies.bcn.cat
# 22         http://museuculturesmon.bcn.cat
# 23       http://www.museuetnologic.bcn.cat
# 24                      http://www.mmb.cat
# 25            http://museuhistoria.bcn.cat
# 26                                     NaN
# 27            http://museuhistoria.bcn.cat
# 28                    http://www.macba.cat
# 29                    http://www.mhcat.cat
# 30                http://www.museumoto.com
# 31           http://www.museumusica.bcn.es
# 32                        http://mmcat.cat
# 33              http://www.museuegipci.com
# 34           http://www.museumares.bcn.cat
# 35                http://museunacional.cat
# 36          http://www.museuolimpicbcn.cat
# 37         http://www.museupicasso.bcn.cat
# 38                   http://palauguell.cat
# 39       http://www.gencat.cat/palaurobert
# 40                                     NaN
# 41        http://monestirpedralbes.bcn.cat
#
#                                                   Seu  \
# 0                       Arxiu Fotogràfic de Barcelona
# 1            Arxiu Històric de la Ciutat de Barcelona
# 2                                          CaixaForum
# 3                                 Castell de Montjuïc
# 4   Centre de Cultura Contemporània de Barcelona. ...
# 5                                          CosmoCaixa
# 6                 El Born Centre de Cultura i Memòria
# 7        Espais VolART i VolART2. Fundació Vila Casas
# 8           Fabra i Coats - Centre d'Art Contemporani
# 9                              Fundació Antoni Tàpies
# 10                           Fundació Foto Colectania
# 11                               Fundació Fran Daurel
# 12                                 Fundació Joan Miró
# 13                                     Fundació Suñol
# 14             Fundación Mapfre Casa Garriga i Nogués
# 15                         Glòries. Museu del Disseny
# 16                Hash Marihuana Cáñamo & Hemp Museum
# 17                                         La Capella
# 18                                         La Pedrera
# 19                    La Virreina Centre de la Imatge
# 20                    MCNB Jardí Botànic de Barcelona
# 21                                    MCNB Museu Blau
# 22                     MECM Museu de Cultures del Món
# 23                               MECM Museu Etnològic
# 24                     MMB Museu Marítim de Barcelona
# 25                                MUHBA altres espais
# 26                                  MUHBA Oliva Artés
# 27                                MUHBA Plaça del Rei
# 28       Museu d'Art Contemporani de Barcelona. MACBA
# 29                      Museu d'Història de Catalunya
# 30                                   Museu de la Moto
# 31                                 Museu de la Música
# 32                        Museu del Modernisme Català
# 33                          Museu Egipci de Barcelona
# 34                               Museu Frederic Marès
# 35            Museu Nacional d'Art de Catalunya. MNAC
# 36  Museu Olímpic i de l'Esport Joan Antoni Samaranch
# 37                                      Museu Picasso
# 38                                        Palau Güell
# 39                                       Palau Robert
# 40                     Recinte Modernista de Sant Pau
# 41         Reial Monestir de Santa Maria de Pedralbes
#
#                   Districte  NombreExposicionsTemporals
# 0          01. Ciutat Vella                           3
# 1          01. Ciutat Vella                           3
# 2        03. Sants-Montjuïc                          17
# 3        03. Sants-Montjuïc                           4
# 4          01. Ciutat Vella                           5
# 5   05. Sarrià-Sant Gervasi                           7
# 6          01. Ciutat Vella                           5
# 7              02. Eixample                           1
# 8           09. Sant Andreu                           1
# 9              02. Eixample                           4
# 10         01. Ciutat Vella                           4
# 11       03. Sants-Montjuïc                           1
# 12       03. Sants-Montjuïc                          15
# 13             02. Eixample                           8
# 14             02. Eixample                           4
# 15           10. Sant Martí                           5
# 16         01. Ciutat Vella                           2
# 17         01. Ciutat Vella                           4
# 18             02. Eixample                           3
# 19         01. Ciutat Vella                           5
# 20       03. Sants-Montjuïc                           2
# 21           10. Sant Martí                           6
# 22         01. Ciutat Vella                           4
# 23       03. Sants-Montjuïc                           1
# 24         01. Ciutat Vella                           4
# 25      Diversos districtes                           2
# 26           10. Sant Martí                           1
# 27         01. Ciutat Vella                           4
# 28         01. Ciutat Vella                          10
# 29         01. Ciutat Vella                           6
# 30         01. Ciutat Vella                           1
# 31             02. Eixample                           3
# 32             02. Eixample                           3
# 33             02. Eixample                           3
# 34         01. Ciutat Vella                           3
# 35       03. Sants-Montjuïc                           8
# 36       03. Sants-Montjuïc                           5
# 37         01. Ciutat Vella                           3
# 38         01. Ciutat Vella                           1
# 39             02. Eixample                          15
# 40       07. Horta-Guinardó                           2
# 41            04. Les Corts                           2

# %%
collection.insert_many(street_markets.to_dict("records"))

# %%
for d in collection.find():
    print (d)

# %%
collection.delete_many({})
